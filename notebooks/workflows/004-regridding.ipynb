# %%
import xarray as xr
import xesmf as xe
import os
import numpy as np
from pyproj import CRS, Transformer
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/scratch2/mg963/aifs-tp'

# %%
aifs = xr.open_zarr("AIFS_TP_FXX24_DE.zarr", consolidated=True, chunks={})
ifs = xr.open_zarr("IFS_TP_FXX24_DE.zarr", consolidated=True, chunks={})

# %%
obs = xr.open_dataset("../../aifs-data/obs/pr_hyras_1_2025_v6-1_de.nc")

# %%
# Standardize coord names
if "latitude" in aifs.coords: aifs = aifs.rename({"latitude":"lat","longitude":"lon"})
if "latitude" in ifs.coords:  ifs  = ifs.rename({"latitude":"lat","longitude":"lon"})

# %%
# Clean, explicit grids: lat/lon as DATA VARS, drop all other coords
grid_in = xr.Dataset(
    data_vars=dict(
        lat=(["y","x"],  obs["lat"].values.astype("float64")),
        lon=(["y","x"],  obs["lon"].values.astype("float64")),
    ),
    coords=dict(
        y=obs["y"].values.astype("float64"),
        x=obs["x"].values.astype("float64"),
    ),
).reset_coords(drop=True)

# %%
# MODEL grid: 1D lat/lon ONLY as data_vars (no coords with same names) ✅
grid_out = xr.Dataset(
    data_vars=dict(
        lat=(("lat",), aifs["lat"].values.astype("float64")),
        lon=(("lon",), aifs["lon"].values.astype("float64")),
    )
)  # note: no coords=... here

# %%
# Build regridder
regridder = xe.Regridder(
    grid_in, grid_out,
    method="nearest_d2s",          # good for precip
    extrap_method=None,          
    # filename="weights_obs_to_aifs_DE_nearest.nc",
    # reuse_weights=True,
    periodic=False,
    ignore_degenerate=True
)


inverse_regridder = xe.Regridder(
    grid_out, grid_in,
    method="bilinear",          # good for precip
    extrap_method=None,          
    # filename="weights_obs_to_aifs_DE_nearest.nc",
    # reuse_weights=True,
    periodic=False,
    ignore_degenerate=True
)

# %%
# 1) Build a 0/1 mask on the HYRAS grid (time-independent)
#    1 where pr is finite on a sample time; NaN elsewhere
src_mask = xr.where(np.isfinite(obs["pr"].isel(time=0)), 1.0, np.nan).astype("float32")

# 2) Regrid the mask to the model grid  -> should be (lat, lon) with 1 or NaN
footprint = regridder(src_mask).rename("footprint")

# Optional cleanup: ensure strict 1/NaN
footprint = xr.where(footprint > 0, 1.0, np.nan)

# 3) Regrid precipitation and apply the footprint mask
obs_on_model = regridder(obs["pr"]).where(np.isfinite(footprint)).rename("pr_on_model")

aifs_crop = aifs.where(np.isfinite(footprint))
ifs_crop = ifs.where(np.isfinite(footprint))

# %%
src_mask = xr.where(np.isfinite(obs["pr"].isel(time=0)), 1.0, np.nan).astype("float32")

aifs_on_obs = inverse_regridder(aifs.tp)
aifs_on_obs_crop = aifs_on_obs.where(np.isfinite(src_mask))

ifs_on_obs = inverse_regridder(ifs.tp)
ifs_on_obs_crop = ifs_on_obs.where(np.isfinite(src_mask))
# Out:
# /scratch2/mg963/conda_envs/envs/regrid/lib/python3.11/site-packages/xarray/computation/apply_ufunc.py:310: PerformanceWarning: Regridding is increasing the number of chunks by a factor of 24.0, you might want to specify sizes in `output_chunks` in the regridder call. Default behaviour is to preserve the chunk sizes from the input (33, 28).
#   result_var = func(*data_vars)
# /scratch2/mg963/conda_envs/envs/regrid/lib/python3.11/site-packages/dask/array/routines.py:333: PerformanceWarning: Increasing number of chunks by factor of 24
#   intermediate = blockwise(
# /scratch2/mg963/conda_envs/envs/regrid/lib/python3.11/site-packages/xarray/computation/apply_ufunc.py:310: PerformanceWarning: Regridding is increasing the number of chunks by a factor of 24.0, you might want to specify sizes in `output_chunks` in the regridder call. Default behaviour is to preserve the chunk sizes from the input (33, 28).
#   result_var = func(*data_vars)
# /scratch2/mg963/conda_envs/envs/regrid/lib/python3.11/site-packages/dask/array/routines.py:333: PerformanceWarning: Increasing number of chunks by factor of 24
#   intermediate = blockwise(

# %%
# OPTION 1
aifs_tp = aifs_crop["tp"]
ifs_tp = ifs_crop["tp"]*1000
obs_tp = obs_on_model/1000

# %%
# OPTION 2
aifs_interp_tp = aifs_on_obs_crop
ifs_interp_tp = ifs_on_obs_crop * 1000
obs_tp = obs.pr/1000

# %%
# OPTION 1
aifs_aln, ifs_aln, obs_aln = xr.align(aifs_tp, ifs_tp, obs_tp, join="inner")

# %%
# OPTION 2
aifs_aln, ifs_aln, obs_aln = xr.align(aifs_interp_tp, ifs_interp_tp, obs_tp, join="inner")

# %%
# build a single Dataset with both aligned arrays
pair = xr.Dataset({"aifs": aifs_aln, 
                   "ifs": ifs_aln, 
                   "obs": obs_aln})

# mask where either side is NaN (optional but recommended)
pair = pair.where(np.isfinite(pair["aifs"]) & np.isfinite(pair["ifs"]) & np.isfinite(pair["obs"]))

# %%
pair.to_zarr("AIFS_IFS_OBS_GERMANY_HIGHRES.zarr", mode="w", consolidated=True)
# Out:
# /scratch2/mg963/conda_envs/envs/regrid/lib/python3.11/site-packages/zarr/api/asynchronous.py:244: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(

# %%
pair.to_netcdf("AIFS_IFS_OBS_GERMANY_HIGHRES.nc")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /scratch2/mg963/conda_envs/envs/regrid/lib/python3.11/site-packages/xarray/backends/writers.py:450, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf, auto_complex)
#     448         return writer, store
# --> 450     writes = writer.sync(compute=compute)
#     452 finally:
#
# File /scratch2/mg963/conda_envs/envs/regrid/lib/python3.11/site-packages/xarray/backends/common.py:416, in ArrayWriter.sync(self, compute, chunkmanager_store_kwargs)
#     414     chunkmanager_store_kwargs = {}
# --> 416 delayed_store = chunkmanager.store(
#     417     self.sources,
#     418     self.targets,
#     419     lock=self.lock,
#     420     compute=compute,
#     421     flush=True,
#     422     regions=self.regions,
#     423     **chunkmanager_store_kwargs,
#     424 )
#     425 self.sources = []
#
# File /scratch2/mg963/conda_envs/envs/regrid/lib/python3.11/site-packages/xarray/namedarray/daskmanager.py:247, in DaskManager.store(self, sources, targets, **kwargs)
#     245 from dask.array import store
# --> 247 return store(
#     248     sources=sources,
#     249     targets=targets,
#     250     **kwargs,
#     251 )
#
# File /scratch2/mg963/conda_envs/envs/regrid/lib/python3.11/site-packages/dask/array/core.py:1221, in store(***failed resolving arguments***)
#    1219 import dask
# -> 1221 dask.compute(arrays, **kwargs)
#    1222 return None
#
# File /scratch2/mg963/conda_envs/envs/regrid/lib/python3.11/site-packages/dask/base.py:681, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     679     keys = list(flatten(expr.__dask_keys__()))
# --> 681     results = schedule(expr, keys, **kwargs)
#     683 return repack(results)
#
# File /scratch2/mg963/conda_envs/envs/regrid/lib/python3.11/queue.py:171, in Queue.get(self, block, timeout)
#     170     while not self._qsize():
# --> 171         self.not_empty.wait()
#     172 elif timeout < 0:
#
# File /scratch2/mg963/conda_envs/envs/regrid/lib/python3.11/threading.py:327, in Condition.wait(self, timeout)
#     326 if timeout is None:
# --> 327     waiter.acquire()
#     328     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 pair.to_netcdf("AIFS_IFS_OBS_GERMANY_HIGHRES.nc")
#
# File /scratch2/mg963/conda_envs/envs/regrid/lib/python3.11/site-packages/xarray/core/dataset.py:2104, in Dataset.to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf, auto_complex)
#    2101     encoding = {}
#    2102 from xarray.backends.writers import to_netcdf
# -> 2104 return to_netcdf(  # type: ignore[return-value]  # mypy cannot resolve the overloads:(
#    2105     self,
#    2106     path,
#    2107     mode=mode,
#    2108     format=format,
#    2109     group=group,
#    2110     engine=engine,
#    2111     encoding=encoding,
#    2112     unlimited_dims=unlimited_dims,
#    2113     compute=compute,
#    2114     multifile=False,
#    2115     invalid_netcdf=invalid_netcdf,
#    2116     auto_complex=auto_complex,
#    2117 )
#
# File /scratch2/mg963/conda_envs/envs/regrid/lib/python3.11/site-packages/xarray/backends/writers.py:455, in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf, auto_complex)
#     453 if not multifile and not autoclose:  # type: ignore[redundant-expr,unused-ignore]
#     454     if compute:
# --> 455         store.close()
#     456     else:
#     457         store.sync()
#
# File /scratch2/mg963/conda_envs/envs/regrid/lib/python3.11/site-packages/xarray/backends/netCDF4_.py:672, in NetCDF4DataStore.close(self, **kwargs)
#     671 def close(self, **kwargs):
# --> 672     self._manager.close(**kwargs)
#
# File /scratch2/mg963/conda_envs/envs/regrid/lib/python3.11/site-packages/xarray/backends/file_manager.py:242, in CachingFileManager.close(self, needs_lock)
#     240 file = self._cache.pop(self._key, default)
#     241 if file is not None:
# --> 242     file.close()
#
# KeyboardInterrupt:
